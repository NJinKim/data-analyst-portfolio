# %%
import pandas as pd 
import numpy as np

# %%
pd.read_csv('./data/tableau_job.csv')
# Out:
#      job_id  user_id category  area  rooms  bathrooms housing_type   price  \
# 0         1       99       빌라  31.2      2          2        본인 소유   77642
# 1         2      224       빌라  41.5      2          1           임대   33752
# 2         3      235       빌라  92.0      2          3           임대  198456
# 3         4       34       빌라  86.4      5          2        본인 소유  202468
# 4         5       57       빌라  40.1      5          1           임대  234137
# ..      ...      ...      ...   ...    ...        ...          ...     ...
# 926     927       74     단독주택  82.3      2          1           임대   24677
# 927     928      231     단독주택  35.2      5          1           임대  281484
# 928     929      186     단독주택  87.3      5          1        본인 소유  251876
# 929     930      174     단독주택  81.6      5          3        본인 소유  275415
# 930     931       50     단독주택  79.9      5          1           임대  240144
#
#       post_date   city district    address   latitude   longitude
# ...
